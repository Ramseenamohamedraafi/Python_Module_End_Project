# %% [markdown]
# #                                   Module End Project

# %% [markdown]
# # Providing a dataset of employees working in ABC company. It consists of 458 rows and 9 columns. The company needs the detailed report and explanation of their employees in each team.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
employee_details=pd.read_csv('myexcel - myexcel.csv.csv')
employee_details
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# 2    Boston University        NaN
# 3        Georgia State  1148640.0
# 4                  NaN  5000000.0
# ..                 ...        ...
# 453             Butler  2433333.0
# 454                NaN   900000.0
# 455                NaN  2900000.0
# 456             Kansas   947276.0
# 457             Kansas   947276.0
#
# [458 rows x 9 columns]

# %%
employee_details.duplicated().sum()
# Out:
# 0

# %%
employee_details['Height']=np.random.randint(150,180,size=len(employee_details))

# %%
employee_details.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %% [markdown]
# # 1.How many are there in each Team and the percentage splitting with respect to the total employees.

# %%
number=employee_details.Team.value_counts()
percentage_split=(number/len(employee_details))*100
Team=pd.DataFrame({'Team':number.index,'counts':number.values,'percentage':percentage_split.values})
Team
# Out:
#                       Team  counts  percentage
# 0     New Orleans Pelicans      19    4.148472
# 1        Memphis Grizzlies      18    3.930131
# 2                Utah Jazz      16    3.493450
# 3          New York Knicks      16    3.493450
# 4          Milwaukee Bucks      16    3.493450
# 5            Brooklyn Nets      15    3.275109
# 6   Portland Trail Blazers      15    3.275109
# 7    Oklahoma City Thunder      15    3.275109
# 8           Denver Nuggets      15    3.275109
# 9       Washington Wizards      15    3.275109
# 10              Miami Heat      15    3.275109
# 11       Charlotte Hornets      15    3.275109
# 12           Atlanta Hawks      15    3.275109
# 13       San Antonio Spurs      15    3.275109
# 14         Houston Rockets      15    3.275109
# 15          Boston Celtics      15    3.275109
# 16          Indiana Pacers      15    3.275109
# 17         Detroit Pistons      15    3.275109
# 18     Cleveland Cavaliers      15    3.275109
# 19           Chicago Bulls      15    3.275109
# 20        Sacramento Kings      15    3.275109
# 21            Phoenix Suns      15    3.275109
# 22      Los Angeles Lakers      15    3.275109
# 23    Los Angeles Clippers      15    3.275109
# 24   Golden State Warriors      15    3.275109
# 25         Toronto Raptors      15    3.275109
# 26      Philadelphia 76ers      15    3.275109
# 27        Dallas Mavericks      15    3.275109
# 28           Orlando Magic      14    3.056769
# 29  Minnesota Timberwolves      14    3.056769

# %% [markdown]
# # 2.Segregate the employees w.r.t different positions.

# %%
Position_count=employee_details.groupby('Position')
print(Position_count.value_counts())
# Out:
# Position  Name                 Team                  Number  Age  Height  Weight  College           Salary
# C         Al Horford           Atlanta Hawks         15      30   06-Oct  245     Florida           12000000.0    1
#           Alan Williams        Phoenix Suns          15      23   06-Aug  260     UC Santa Barbara  83397.0       1
#           Willie Cauley-Stein  Sacramento Kings      0       22   7-0     240     Kentucky          3398280.0     1
#           Tyler Zeller         Boston Celtics        44      26   7-0     253     North Carolina    2616975.0     1
#           Tim Duncan           San Antonio Spurs     21      40   06-Nov  250     Wake Forest       5250000.0     1
#                                                                                                                  ..
# SG        Gary Harris          Denver Nuggets        14      21   06-Apr  210     Michigan State    1584480.0     1
#           Garrett Temple       Washington Wizards    17      30   06-Jun  195     LSU               1100602.0     1
#           Evan Turner          Boston Celtics        11      27   06-Jul  220     Ohio State        3425510.0     1
#           Eric Gordon          New Orleans Pelicans  10      27   06-Apr  215     Indiana           15514031.0    1
#           Wesley Matthews      Dallas Mavericks      23      29   06-May  220     Marquette         16407500.0    1
# Name: count, Length: 365, dtype: int64

# %% [markdown]
# # 3.Find from which age group most of the employees belong to.

# %%
age_grp=pd.cut(employee_details['Age'],bins=[18,25,35,45,55,65])
age_grp_counts=age_grp.value_counts()
print(age_grp_counts)
# Out:
# Age
# (25, 35]    235
# (18, 25]    200
# (35, 45]     23
# (45, 55]      0
# (55, 65]      0
# Name: count, dtype: int64

# %% [markdown]
# # 4.Find out under which team and position, spending in terms of salary is high.

# %%
grp_data=employee_details.groupby(['Team','Position'])['Salary'].sum()
max_spending=grp_data.idxmax()
team_with_highest_spending,position_with_highest_spending=max_spending
print("Team with highest spending:",team_with_highest_spending)
print("Position with highest spending:",position_with_highest_spending)
# Out:
# Team with highest spending: Los Angeles Lakers
# Position with highest spending: SF

# %% [markdown]
# # 5.Find if there is any correlation between age and salary , represent it visually.

# %%
employee_details.plot.scatter(x='Age',y='Salary')
plt.title('correlation between AGE and SALARY')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()
